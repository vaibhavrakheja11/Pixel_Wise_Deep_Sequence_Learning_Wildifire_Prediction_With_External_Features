# %%
from keras.models import Sequential
from keras.callbacks import Callback
from keras.layers import Conv2D, MaxPooling2D, Dropout, Dense, Flatten, UpSampling2D
from keras import backend as K
import tensorflow as tf
import tarfile
import random
import glob
import subprocess
import os
from PIL import Image
import numpy as np
from matplotlib.pyplot import imshow, figure
import cv2
import matplotlib.pyplot as plt
import logging
from keras.preprocessing.image import load_img
# Out:
# Using TensorFlow backend.

# %%
from PIL import Image
im = Image.open('Data/train_data/Fire_12_jd_181.tif')
im.show()

# %%
t = np.array(Image.open('Data/train_data/Fire_12_jd_181.tif').getdata()).reshape([128,128])

# %%
#d= t.reshape([128,128])
#im = Image.fromarray(d, mode='F') # float32
#im.save("Fire_12_jd_181.tiff", "TIFF")
plt.imshow(t, cmap="gray")
plt.show()

# %%
t.shape
# Out:
# (128, 128)

# %%
# k = t.reshape((128,128,1))
# im = Image.fromarray(k, mode='F') 
# im.save("test3.tiff", "TIFF")
# k.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-1970b3218849> in <module>
#       1 k = t.reshape((128,128,1))
# ----> 2 im = Image.fromarray(k, mode='F')
#       3 im.save("test3.tiff", "TIFF")
#       4 k.shape
#
# ~/anaconda3/lib/python3.7/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2659         ndmax = 4
#    2660     if ndim > ndmax:
# -> 2661         raise ValueError("Too many dimensions: %d > %d." % (ndim, ndmax))
#    2662
#    2663     size = shape[1], shape[0]
#
# ValueError: Too many dimensions: 3 > 2.

# %%
t = np.concatenate([k,k,k,k,k,k,k],axis=-1)
t.shape
# Out:
# (128, 128, 7)

# %%
cat_dirs = glob.glob(train_dir + "/*")
counter = 0
# if (counter+2 >= len(cat_dirs)):
#     counter = 0
print("kjo")
for i in range(1):
    input_imgs = glob.glob(cat_dirs[0 + i] + "/Fire_*")
    print("hh")
    print(input_imgs[0])
    for f in input_imgs:
        print(f)
        print("---xx---xx---xx---xx---")
#files = [f for f in glob.glob(cat_dirs + "/Fire_*.tif", recursive=True)]
# Out:
# kjo
# hh
# Data/train_data_div/fire_22/Fire_26_jd_179.png
# Data/train_data_div/fire_22/Fire_26_jd_179.png
# ---xx---xx---xx---xx---
# Data/train_data_div/fire_22/Fire_26_jd_180.png
# ---xx---xx---xx---xx---
# Data/train_data_div/fire_22/Fire_26_jd_181.png
# ---xx---xx---xx---xx---
# Data/train_data_div/fire_22/Fire_26_jd_183.png
# ---xx---xx---xx---xx---
# Data/train_data_div/fire_22/Fire_26_jd_182.png
# ---xx---xx---xx---xx---

# %%
#initialise params
hyperparams = {"num_epochs": 10, 
          "batch_size": 2,
          "height": 480,
          "width": 480}

config=hyperparams

# %%
#load data
val_dir = 'Data/test_data_div'
train_dir = 'Data/train_data_div'
test_dir = 'Data/eval_data_div'

# %%
#check image format
img = load_img(train_dir + '/fire_01/Fire_12_jd_174.png')
print(type(img))
print(img.format)
print(img.mode)
print(img.size)
# Out:
# <class 'PIL.Image.Image'>
# None
# RGB
# (480, 480)

# %%
#define generator 
def my_generator(batch_size, img_dir):
    """A generator that returns 5 images plus a result image"""
    cat_dirs = glob.glob(img_dir + "/*")
    counter = 0
    while True:
        input_images = np.zeros(
            (batch_size, config['width'], config['height'], 3 * 5))
        output_images = np.zeros((batch_size, config['width'], config['height'], 3))
#         random.shuffle(cat_dirs)
        if (counter+batch_size >= len(cat_dirs)):
            counter = 0
        for i in range(batch_size):
            input_imgs = glob.glob(cat_dirs[counter + i] + "/Fire_*")
            imgs = [Image.open(img).convert('RGB') for img in sorted(input_imgs)]
            
            #print(sorted(input_imgs))
#             print(img , " : " , input_images[i].shape, 'ImAGE NAME :-', sorted(input_images))
            
            input_images[i] = np.concatenate(imgs, axis=2)
            output_images[i] = np.array(Image.open(
                cat_dirs[counter + i] + "/fire_result.tiff").convert('RGB'))
            input_images[i] /= 255.
            output_images[i] /= 255.
        yield (input_images, output_images)
        counter += batch_size
        
steps_per_epoch = len(glob.glob(train_dir + "/*")) // config['batch_size']
validation_steps = len(glob.glob(val_dir + "/*")) // config['batch_size']

# %%
#len(glob.glob(train_dir + "/*"))//config['batch_size']

# %%
#len(glob.glob(val_dir + "/*")) // config['batch_size']

# %%
#callback to log the images

class ImageCallback(Callback):
    def on_epoch_end(self, epoch, logs):
        validation_X, validation_y = next(
            my_generator(5, val_dir))
        output = self.model.predict(validation_X)
        print(output.shape)
#         wandb.log({
#             "input": [wandb.Image(np.concatenate(np.split(c, 5, axis=2), axis=1)) for c in validation_X],
#             "output": [wandb.Image(np.concatenate([validation_y[i], o], axis=1)) for i, o in enumerate(output)]
#         }, commit=False)

# %%
#Test the generator
gen = my_generator(2, train_dir)
input, output = next(gen)


videos, next_frame = next(gen)
print(videos[0].shape)
print(next_frame[0].shape)

figure()
imshow(videos[0][:,:,0:3])
figure()
imshow(videos[0][:,:,3:6])
figure()
imshow(videos[0][:,:,6:9])
figure()
imshow(videos[0][:,:,9:12])
figure()
imshow(videos[0][:,:,12:15])

figure()
imshow(next_frame[0][:,:,0:3])

# gen = my_generator(2, train_dir)
# videos, next_frame = next(gen)
# print(videos[0].shape)
# print(next_frame[0].shape)

# figure()
# imshow(videos[0][:,:,0:4])
# figure()
# imshow(videos[0][:,:,4:8])
# figure()
# imshow(videos[0][:,:,8:12])
# figure()
# imshow(videos[0][:,:,12:16])
# figure()
# imshow(videos[0][:,:,16:20])

# figure()
# imshow(next_frame[0][:,:,0:4])
# Out:
# (480, 480, 15)
# (480, 480, 3)

# %%
# # Function for measuring how similar two images are
# def perceptual_distance(y_true, y_pred):
#     y_true *= 255.
#     y_pred *= 255.
#     rmean = (y_true[:, :, :, 0] + y_pred[:, :, :, 0]) / 2
#     r = y_true[:, :, :, 0] - y_pred[:, :, :, 0]
#     g = y_true[:, :, :, 1] - y_pred[:, :, :, 1]
#     b = y_true[:, :, :, 2] - y_pred[:, :, :, 2]
    
    

#     return K.mean(K.sqrt((((512+rmean)*r*r)/256) + 4*g*g + (((767-rmean)*b*b)/256)))

# %%
# Function for measuring how similar two images are uttu
def perceptual_distance(y_true, y_pred):
    y_pred = tf.convert_to_tensor(y_pred, np.float32)
    y_true = tf.convert_to_tensor(y_true, np.float32)
    y_true *= 255.
    y_pred *= 255.
    rmean = (y_true[:, :, :, 0] + y_pred[:, :, :, 0]) / 2
    r = y_true[:, :, :, 0] - y_pred[:, :, :, 0]
    g = y_true[:, :, :, 1] - y_pred[:, :, :, 1]
    b = y_true[:, :, :, 2] - y_pred[:, :, :, 2]
    
    

    return K.mean(K.sqrt((((512+rmean)*r*r)/256) + 4*g*g + (((767-rmean)*b*b)/256)))

# %%
# simple conv2D model 2 layers
config=hyperparams

model = Sequential()
model.add(Conv2D(10, (3, 3), activation='relu', padding='same', input_shape=(config['height'], config['width'], 5 * 3)))
model.add(Conv2D(3, (3, 3), activation='relu', padding='same')),

model.compile(optimizer='adam', loss='mse', metrics=[perceptual_distance])

model.fit_generator(my_generator(config['batch_size'], train_dir),
                    steps_per_epoch=steps_per_epoch,
                    epochs=config['num_epochs'], callbacks=[
    ImageCallback()],
    validation_steps=validation_steps,
    validation_data=my_generator(config['batch_size'], val_dir))
# Out:
# Epoch 1/10
# 29/29 [==============================] - 10s 345ms/step - loss: 0.0478 - perceptual_distance: 114.3096 - val_loss: 0.0136 - val_perceptual_distance: 46.9686
# (5, 480, 480, 3)
# Epoch 2/10
# 29/29 [==============================] - 9s 316ms/step - loss: 0.0110 - perceptual_distance: 33.1332 - val_loss: 0.0074 - val_perceptual_distance: 23.9268
# (5, 480, 480, 3)
# Epoch 3/10
# 29/29 [==============================] - 9s 313ms/step - loss: 0.0064 - perceptual_distance: 22.4193 - val_loss: 0.0064 - val_perceptual_distance: 46.2383
# (5, 480, 480, 3)
# Epoch 4/10
# 29/29 [==============================] - 9s 317ms/step - loss: 0.0048 - perceptual_distance: 25.0607 - val_loss: 0.0037 - val_perceptual_distance: 19.4176
# (5, 480, 480, 3)
# Epoch 5/10
# 29/29 [==============================] - 9s 313ms/step - loss: 0.0036 - perceptual_distance: 15.9789 - val_loss: 0.0029 - val_perceptual_distance: 13.6960
# (5, 480, 480, 3)
# Epoch 6/10
# 29/29 [==============================] - 9s 313ms/step - loss: 0.0030 - perceptual_distance: 14.4879 - val_loss: 0.0024 - val_perceptual_distance: 12.3002
# (5, 480, 480, 3)
# Epoch 7/10
# 29/29 [==============================] - 9s 313ms/step - loss: 0.0027 - perceptual_distance: 13.9442 - val_loss: 0.0022 - val_perceptual_distance: 13.5805
# (5, 480, 480, 3)
# Epoch 8/10
# 29/29 [==============================] - 9s 318ms/step - loss: 0.0025 - perceptual_distance: 13.2132 - val_loss: 0.0020 - val_perceptual_distance: 13.3134
# (5, 480, 480, 3)
# Epoch 9/10
# 29/29 [==============================] - 9s 317ms/step - loss: 0.0023 - perceptual_distance: 13.4581 - val_loss: 0.0018 - val_perceptual_distance: 11.7165
# (5, 480, 480, 3)
# Epoch 10/10
# 29/29 [==============================] - 9s 316ms/step - loss: 0.0022 - perceptual_distance: 13.5632 - val_loss: 0.0017 - val_perceptual_distance: 11.4653
# (5, 480, 480, 3)

# %%
#local testing block uttu
cat_dirs = glob.glob(test_dir + "/*")

fig, ax = plt.subplots(len(cat_dirs), 2 ,figsize=(45,45))
print(len(cat_dirs))
for i, each_dir in enumerate(cat_dirs):
    input_images = np.zeros(
            (1, config['width'], config['height'], 3 * 5))
    output_images = np.zeros((1, config['width'], config['height'], 3))

    #input_imgs = glob.glob(each_dir + "/cat_[0-5]*")
    input_imgs = glob.glob(each_dir + "/Fire_*")
    imgs = [Image.open(img).convert('RGB') for img in sorted(input_imgs)]
    print(input_imgs)
    input_images[0] = np.concatenate(imgs, axis=2)
    output_images[0] = np.array(Image.open(
        each_dir + "/fire_result.png").convert('RGB'))
    input_images[0] /= 255.
    output_images[0] /= 255.    

    output_pred = model.predict(input_images)
    
    ax[i, 0].imshow(output_images[0])
    ax[i, 1].imshow(output_pred[0])

    a = perceptual_distance(output_images, output)
    print("Perceptual Distance :-", K.get_value(a))
    
    
plt.show()
# Out:
# W1123 16:20:24.634800 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 14
# ['Data/eval_data_div/fire_78/Fire_38_jd_179.png', 'Data/eval_data_div/fire_78/Fire_38_jd_178.png', 'Data/eval_data_div/fire_78/Fire_38_jd_180.png', 'Data/eval_data_div/fire_78/Fire_38_jd_181.png', 'Data/eval_data_div/fire_78/Fire_38_jd_182.png']
# W1123 16:20:28.458336 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 14.1918335
# ['Data/eval_data_div/fire_85/Fire_48_jd_188.png', 'Data/eval_data_div/fire_85/Fire_48_jd_185.png', 'Data/eval_data_div/fire_85/Fire_48_jd_184.png', 'Data/eval_data_div/fire_85/Fire_48_jd_186.png', 'Data/eval_data_div/fire_85/Fire_48_jd_187.png']
# W1123 16:20:32.064317 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 15.746527
# ['Data/eval_data_div/fire_82/Fire_38_jd_186.png', 'Data/eval_data_div/fire_82/Fire_38_jd_185.png', 'Data/eval_data_div/fire_82/Fire_38_jd_184.png', 'Data/eval_data_div/fire_82/Fire_38_jd_183.png', 'Data/eval_data_div/fire_82/Fire_38_jd_182.png']
# W1123 16:20:35.511942 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 12.543138
# ['Data/eval_data_div/fire_77/Fire_38_jd_179.png', 'Data/eval_data_div/fire_77/Fire_38_jd_178.png', 'Data/eval_data_div/fire_77/Fire_38_jd_180.png', 'Data/eval_data_div/fire_77/Fire_38_jd_181.png', 'Data/eval_data_div/fire_77/Fire_38_jd_177.png']
# W1123 16:20:39.003683 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 14.19885
# ['Data/eval_data_div/fire_79/Fire_38_jd_179.png', 'Data/eval_data_div/fire_79/Fire_38_jd_180.png', 'Data/eval_data_div/fire_79/Fire_38_jd_181.png', 'Data/eval_data_div/fire_79/Fire_38_jd_183.png', 'Data/eval_data_div/fire_79/Fire_38_jd_182.png']
# W1123 16:20:42.482836 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 12.5151415
# ['Data/eval_data_div/fire_90/Fire_48_jd_189.png', 'Data/eval_data_div/fire_90/Fire_48_jd_191.png', 'Data/eval_data_div/fire_90/Fire_48_jd_190.png', 'Data/eval_data_div/fire_90/Fire_48_jd_192.png', 'Data/eval_data_div/fire_90/Fire_48_jd_193.png']
# W1123 16:20:46.010903 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 14.755028
# ['Data/eval_data_div/fire_91/Fire_48_jd_194.png', 'Data/eval_data_div/fire_91/Fire_48_jd_191.png', 'Data/eval_data_div/fire_91/Fire_48_jd_190.png', 'Data/eval_data_div/fire_91/Fire_48_jd_192.png', 'Data/eval_data_div/fire_91/Fire_48_jd_193.png']
# W1123 16:20:49.557914 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 14.173732
# ['Data/eval_data_div/fire_88/Fire_48_jd_189.png', 'Data/eval_data_div/fire_88/Fire_48_jd_188.png', 'Data/eval_data_div/fire_88/Fire_48_jd_191.png', 'Data/eval_data_div/fire_88/Fire_48_jd_190.png', 'Data/eval_data_div/fire_88/Fire_48_jd_187.png']
# W1123 16:20:53.139105 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 14.912887
# ['Data/eval_data_div/fire_81/Fire_38_jd_185.png', 'Data/eval_data_div/fire_81/Fire_38_jd_184.png', 'Data/eval_data_div/fire_81/Fire_38_jd_181.png', 'Data/eval_data_div/fire_81/Fire_38_jd_183.png', 'Data/eval_data_div/fire_81/Fire_38_jd_182.png']
# W1123 16:20:56.763465 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 12.646218
# ['Data/eval_data_div/fire_86/Fire_48_jd_189.png', 'Data/eval_data_div/fire_86/Fire_48_jd_188.png', 'Data/eval_data_div/fire_86/Fire_48_jd_185.png', 'Data/eval_data_div/fire_86/Fire_48_jd_186.png', 'Data/eval_data_div/fire_86/Fire_48_jd_187.png']
# W1123 16:21:00.426703 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 15.888488
# ['Data/eval_data_div/fire_87/Fire_48_jd_189.png', 'Data/eval_data_div/fire_87/Fire_48_jd_188.png', 'Data/eval_data_div/fire_87/Fire_48_jd_190.png', 'Data/eval_data_div/fire_87/Fire_48_jd_186.png', 'Data/eval_data_div/fire_87/Fire_48_jd_187.png']
# W1123 16:21:04.123740 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 15.728222
# ['Data/eval_data_div/fire_80/Fire_38_jd_184.png', 'Data/eval_data_div/fire_80/Fire_38_jd_180.png', 'Data/eval_data_div/fire_80/Fire_38_jd_181.png', 'Data/eval_data_div/fire_80/Fire_38_jd_183.png', 'Data/eval_data_div/fire_80/Fire_38_jd_182.png']
# W1123 16:21:07.967225 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 12.559116
# ['Data/eval_data_div/fire_89/Fire_48_jd_189.png', 'Data/eval_data_div/fire_89/Fire_48_jd_188.png', 'Data/eval_data_div/fire_89/Fire_48_jd_191.png', 'Data/eval_data_div/fire_89/Fire_48_jd_190.png', 'Data/eval_data_div/fire_89/Fire_48_jd_192.png']
# W1123 16:21:11.867993 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 14.786881
# ['Data/eval_data_div/fire_92/Fire_48_jd_194.png', 'Data/eval_data_div/fire_92/Fire_48_jd_195.png', 'Data/eval_data_div/fire_92/Fire_48_jd_191.png', 'Data/eval_data_div/fire_92/Fire_48_jd_192.png', 'Data/eval_data_div/fire_92/Fire_48_jd_193.png']
# Perceptual Distance :- 13.388254

# %%
# test_gen = test_generator(1, test_dir)
# # test_img_set, output_img = next(test_gen)
# # output = model.predict(test_img_set)

# for test_imgs, output_imgs in test_gen:
#     output = model.predict(test_imgs)
#     a = perceptual_distance(output_img, output)
#     print("Perceptual Distance :-", K.get_value(a))

# %%
#plt.imshow(output[0])
#plt.imshow(output_img[0])

# %%
# Baseline model - just return the last layer

from keras.layers import Lambda, Reshape, Permute

def slice(x):
    return x[:,:,:,:, -1]

config=hyperparams

model=Sequential()
model.add(Reshape((375,375,5,3), input_shape=(config['height'], config['width'], 5 * 3)))
model.add(Permute((1,2,4,3)))
model.add(Lambda(slice, input_shape=(375,375,3,5), output_shape=(375,375,3)))

model.compile(optimizer='adam', loss='mse', metrics=[perceptual_distance])

model.fit_generator(my_generator(config['batch_size'], train_dir),
                    steps_per_epoch=steps_per_epoch,
                    epochs=config['num_epochs'], callbacks=[
    ImageCallback()],
    validation_steps=validation_steps,
    validation_data=my_generator(config['batch_size'], val_dir))

# %%
from keras.layers import Lambda, Reshape, Permute

def slice(x):
    return x[:,:,:,:, -1]

config=hyperparams

model=Sequential()
model.add(Reshape((375,375,5,3), input_shape=(config['height'], config['width'], 5 * 3)))
model.add(Permute((1,2,4,3)))
model.add(Lambda(slice, input_shape=(375,375,3,5), output_shape=(375,375,3)))

model.compile(optimizer='adam', loss='mse', metrics=[perceptual_distance])

model.fit_generator(my_generator(config['batch_size'], train_dir),
                    steps_per_epoch=steps_per_epoch//4,
                    epochs=config['num_epochs'], callbacks=[
    ImageCallback()],
    validation_steps=validation_steps//4,
    validation_data=my_generator(config['batch_size'], val_dir))

# %%
#checking the perpetual distance of the predictions made by Baseline model-1

cat_dirs = glob.glob(test_dir + "/*")

fig, ax = plt.subplots(len(cat_dirs), len(cat_dirs), )

for i, each_dir in enumerate(cat_dirs):
    input_images = np.zeros(
            (1, config['width'], config['height'], 3 * 5))
    output_images = np.zeros((1, config['width'], config['height'], 3))

    input_imgs = glob.glob(each_dir + "/cat_[0-5]*")
    imgs = [Image.open(img).convert('RGB') for img in sorted(input_imgs)]

    input_images[0] = np.concatenate(imgs, axis=2)
    output_images[0] = np.array(Image.open(
        each_dir + "/cat_result.jpg").convert('RGB'))
    input_images[0] /= 255.
    output_images[0] /= 255.    

    output_pred = model.predict(input_images)
    
    ax[i, 0].imshow(output_images[0])
    ax[i, 1].imshow(output_pred[0])

    a = perceptual_distance(output_images, output)
    print("Perceptual Distance :-", K.get_value(a))
    
    
plt.show()

# %%
#Just return the last layer, functional style

from keras.layers import Lambda, Reshape, Permute, Input
from keras.models import Model

def slice(x):
    return x[:,:,:,:, -1]

config=hyperparams


inp = Input((config['height'], config['width'], 5 * 3))
reshaped = Reshape((375,375,5,3))(inp)
permuted = Permute((1,2,4,3))(reshaped)
last_layer = Lambda(slice, input_shape=(375,375,3,5), output_shape=(375,375,3))(permuted)
model=Model(inputs=[inp], outputs=[last_layer])

model.compile(optimizer='adam', loss='mse', metrics=[perceptual_distance])

model.fit_generator(my_generator(config['batch_size'], train_dir),
                    steps_per_epoch=steps_per_epoch,
                    epochs=config['num_epochs'], callbacks=[
    ImageCallback()],
    validation_steps=validation_steps,
    validation_data=my_generator(config['batch_size'], val_dir))

# %%
#checking the perpetual distance of the predictions made by functional model-1

cat_dirs = glob.glob(test_dir + "/*")

fig, ax = plt.subplots(len(cat_dirs), len(cat_dirs), )

for i, each_dir in enumerate(cat_dirs):
    input_images = np.zeros(
            (1, config['width'], config['height'], 3 * 5))
    output_images = np.zeros((1, config['width'], config['height'], 3))

    input_imgs = glob.glob(each_dir + "/cat_[0-5]*")
    imgs = [Image.open(img).convert('RGB') for img in sorted(input_imgs)]

    input_images[0] = np.concatenate(imgs, axis=2)
    output_images[0] = np.array(Image.open(
        each_dir + "/cat_result.jpg").convert('RGB'))
    input_images[0] /= 255.
    output_images[0] /= 255.    

    output_pred = model.predict(input_images)
    
    ax[i, 0].imshow(output_images[0])
    ax[i, 1].imshow(output_pred[0])

    a = perceptual_distance(output_images, output)
    print("Perceptual Distance :-", K.get_value(a))
    
    
plt.show()

# %%
# Conv3D

from keras.layers import Lambda, Reshape, Permute, Input, add, Conv3D
from keras.models import Model

def slice(x):
    return x[:,:,:,:, -1]

hyperparams["num_epochs"] = 20
config=hyperparams


inp = Input((config['height'], config['width'], 5 * 3))
reshaped = Reshape((375,375,5,3))(inp)
permuted = Permute((1,2,4,3))(reshaped)
last_layer = Lambda(slice, input_shape=(375,375,3,5), output_shape=(375,375,3))(permuted)
conv_output = Conv3D(1, (3,3,3), padding="same")(permuted)
conv_output_reshape = Reshape((375,375,3))(conv_output)
combined = add([last_layer, conv_output_reshape])

model=Model(inputs=[inp], outputs=[combined])

model.compile(optimizer='adam', loss='mse', metrics=[perceptual_distance])

model.fit_generator(my_generator(config['batch_size'], train_dir),
                    steps_per_epoch=steps_per_epoch,
                    epochs=config['num_epochs'], callbacks=[
    ImageCallback()],
    validation_steps=validation_steps,
    validation_data=my_generator(config['batch_size'], val_dir))

# %%
# Conv2DLSTM with Gaussian Noise

from keras.layers import Lambda, Reshape, Permute, Input, add, Conv3D, GaussianNoise, ConvLSTM2D
from keras.models import Model

def slice(x):
    return x[:,:,:,:, -1]

config=hyperparams


inp = Input((config['height'], config['width'], 5 * 3))
reshaped = Reshape((480,480,5,3))(inp)
permuted = Permute((1,2,4,3))(reshaped)
noise = GaussianNoise(0.1)(permuted)
last_layer = Lambda(slice, input_shape=(480,480,3,5), output_shape=(480,480,3))(noise)
permuted_2 = Permute((4,1,2,3))(noise)

conv_lstm_output_1 = ConvLSTM2D(6, (3,3), padding='same')(permuted_2)
conv_output = Conv2D(3, (3,3), padding="same")(conv_lstm_output_1)
combined = add([last_layer, conv_output])

model=Model(inputs=[inp], outputs=[combined])

model.compile(optimizer='adam', loss='mse', metrics=[perceptual_distance])

model.fit_generator(my_generator(config['batch_size'], train_dir),
                    steps_per_epoch=steps_per_epoch//4,
                    epochs=config['num_epochs'], callbacks=[
    ImageCallback()],
    validation_steps=validation_steps//4,
    validation_data=my_generator(config['batch_size'], val_dir))
# Out:
# Epoch 1/10
# 7/7 [==============================] - 22s 3s/step - loss: 0.0211 - perceptual_distance: 101.6436 - val_loss: 0.0039 - val_perceptual_distance: 38.5549
# (5, 480, 480, 3)
# Epoch 2/10
# 7/7 [==============================] - 15s 2s/step - loss: 0.0139 - perceptual_distance: 80.0114 - val_loss: 0.0032 - val_perceptual_distance: 41.4544
# (5, 480, 480, 3)
# Epoch 3/10
# 7/7 [==============================] - 15s 2s/step - loss: 0.0130 - perceptual_distance: 78.4424 - val_loss: 0.0012 - val_perceptual_distance: 15.8892
# (5, 480, 480, 3)
# Epoch 4/10
# 7/7 [==============================] - 15s 2s/step - loss: 0.0114 - perceptual_distance: 73.7308 - val_loss: 0.0012 - val_perceptual_distance: 17.8898
# (5, 480, 480, 3)
# Epoch 5/10
# 7/7 [==============================] - 15s 2s/step - loss: 0.0115 - perceptual_distance: 74.0004 - val_loss: 0.0010 - val_perceptual_distance: 16.8152
# (5, 480, 480, 3)
# Epoch 6/10
# 7/7 [==============================] - 15s 2s/step - loss: 0.0114 - perceptual_distance: 73.2543 - val_loss: 7.8891e-04 - val_perceptual_distance: 8.4271
# (5, 480, 480, 3)
# Epoch 7/10
# 7/7 [==============================] - 15s 2s/step - loss: 0.0119 - perceptual_distance: 73.2933 - val_loss: 8.2685e-04 - val_perceptual_distance: 11.4224
# (5, 480, 480, 3)
# Epoch 8/10
# 7/7 [==============================] - 15s 2s/step - loss: 0.0109 - perceptual_distance: 72.3806 - val_loss: 8.2236e-04 - val_perceptual_distance: 9.1767
# (5, 480, 480, 3)
# Epoch 9/10
# 7/7 [==============================] - 15s 2s/step - loss: 0.0111 - perceptual_distance: 72.3446 - val_loss: 6.8815e-04 - val_perceptual_distance: 7.3948
# (5, 480, 480, 3)
# Epoch 10/10
# 7/7 [==============================] - 15s 2s/step - loss: 0.0109 - perceptual_distance: 71.9988 - val_loss: 6.3645e-04 - val_perceptual_distance: 8.0058
# (5, 480, 480, 3)

# %%
cat_dirs = glob.glob(test_dir + "/*")

fig, ax = plt.subplots(len(cat_dirs), 2 ,figsize=(45,45))
print(len(cat_dirs))
for i, each_dir in enumerate(cat_dirs):
    input_images = np.zeros(
            (1, config['width'], config['height'], 3 * 5))
    output_images = np.zeros((1, config['width'], config['height'], 3))

    #input_imgs = glob.glob(each_dir + "/cat_[0-5]*")
    input_imgs = glob.glob(each_dir + "/Fire_*")
    imgs = [Image.open(img).convert('RGB') for img in sorted(input_imgs)]
    print(input_imgs)
    input_images[0] = np.concatenate(imgs, axis=2)
    output_images[0] = np.array(Image.open(
        each_dir + "/fire_result.png").convert('RGB'))
    input_images[0] /= 255.
    output_images[0] /= 255.    

    output_pred = model.predict(input_images)
    
    ax[i, 0].imshow(output_images[0])
    ax[i, 1].imshow(output_pred[0])

    a = perceptual_distance(output_images, output)
    print("Perceptual Distance :-", K.get_value(a))
    
    
plt.show()
# Out:
# 14
# ['Data/eval_data_div/fire_78/Fire_38_jd_179.png', 'Data/eval_data_div/fire_78/Fire_38_jd_178.png', 'Data/eval_data_div/fire_78/Fire_38_jd_180.png', 'Data/eval_data_div/fire_78/Fire_38_jd_181.png', 'Data/eval_data_div/fire_78/Fire_38_jd_182.png']
# W1123 17:07:17.527245 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 14.1918335
# ['Data/eval_data_div/fire_85/Fire_48_jd_188.png', 'Data/eval_data_div/fire_85/Fire_48_jd_185.png', 'Data/eval_data_div/fire_85/Fire_48_jd_184.png', 'Data/eval_data_div/fire_85/Fire_48_jd_186.png', 'Data/eval_data_div/fire_85/Fire_48_jd_187.png']
# W1123 17:07:21.624431 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 15.746527
# ['Data/eval_data_div/fire_82/Fire_38_jd_186.png', 'Data/eval_data_div/fire_82/Fire_38_jd_185.png', 'Data/eval_data_div/fire_82/Fire_38_jd_184.png', 'Data/eval_data_div/fire_82/Fire_38_jd_183.png', 'Data/eval_data_div/fire_82/Fire_38_jd_182.png']
# W1123 17:07:25.707064 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 12.543138
# ['Data/eval_data_div/fire_77/Fire_38_jd_179.png', 'Data/eval_data_div/fire_77/Fire_38_jd_178.png', 'Data/eval_data_div/fire_77/Fire_38_jd_180.png', 'Data/eval_data_div/fire_77/Fire_38_jd_181.png', 'Data/eval_data_div/fire_77/Fire_38_jd_177.png']
# W1123 17:07:29.756458 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 14.19885
# ['Data/eval_data_div/fire_79/Fire_38_jd_179.png', 'Data/eval_data_div/fire_79/Fire_38_jd_180.png', 'Data/eval_data_div/fire_79/Fire_38_jd_181.png', 'Data/eval_data_div/fire_79/Fire_38_jd_183.png', 'Data/eval_data_div/fire_79/Fire_38_jd_182.png']
# W1123 17:07:33.799252 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 12.5151415
# ['Data/eval_data_div/fire_90/Fire_48_jd_189.png', 'Data/eval_data_div/fire_90/Fire_48_jd_191.png', 'Data/eval_data_div/fire_90/Fire_48_jd_190.png', 'Data/eval_data_div/fire_90/Fire_48_jd_192.png', 'Data/eval_data_div/fire_90/Fire_48_jd_193.png']
# W1123 17:07:37.910618 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 14.755028
# ['Data/eval_data_div/fire_91/Fire_48_jd_194.png', 'Data/eval_data_div/fire_91/Fire_48_jd_191.png', 'Data/eval_data_div/fire_91/Fire_48_jd_190.png', 'Data/eval_data_div/fire_91/Fire_48_jd_192.png', 'Data/eval_data_div/fire_91/Fire_48_jd_193.png']
# W1123 17:07:42.044352 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 14.173732
# ['Data/eval_data_div/fire_88/Fire_48_jd_189.png', 'Data/eval_data_div/fire_88/Fire_48_jd_188.png', 'Data/eval_data_div/fire_88/Fire_48_jd_191.png', 'Data/eval_data_div/fire_88/Fire_48_jd_190.png', 'Data/eval_data_div/fire_88/Fire_48_jd_187.png']
# W1123 17:07:46.185856 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 14.912887
# ['Data/eval_data_div/fire_81/Fire_38_jd_185.png', 'Data/eval_data_div/fire_81/Fire_38_jd_184.png', 'Data/eval_data_div/fire_81/Fire_38_jd_181.png', 'Data/eval_data_div/fire_81/Fire_38_jd_183.png', 'Data/eval_data_div/fire_81/Fire_38_jd_182.png']
# W1123 17:07:50.350716 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 12.646218
# ['Data/eval_data_div/fire_86/Fire_48_jd_189.png', 'Data/eval_data_div/fire_86/Fire_48_jd_188.png', 'Data/eval_data_div/fire_86/Fire_48_jd_185.png', 'Data/eval_data_div/fire_86/Fire_48_jd_186.png', 'Data/eval_data_div/fire_86/Fire_48_jd_187.png']
# W1123 17:07:54.545845 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 15.888488
# ['Data/eval_data_div/fire_87/Fire_48_jd_189.png', 'Data/eval_data_div/fire_87/Fire_48_jd_188.png', 'Data/eval_data_div/fire_87/Fire_48_jd_190.png', 'Data/eval_data_div/fire_87/Fire_48_jd_186.png', 'Data/eval_data_div/fire_87/Fire_48_jd_187.png']
# W1123 17:07:58.798729 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 15.728222
# ['Data/eval_data_div/fire_80/Fire_38_jd_184.png', 'Data/eval_data_div/fire_80/Fire_38_jd_180.png', 'Data/eval_data_div/fire_80/Fire_38_jd_181.png', 'Data/eval_data_div/fire_80/Fire_38_jd_183.png', 'Data/eval_data_div/fire_80/Fire_38_jd_182.png']
# W1123 17:08:03.086358 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 12.559116
# ['Data/eval_data_div/fire_89/Fire_48_jd_189.png', 'Data/eval_data_div/fire_89/Fire_48_jd_188.png', 'Data/eval_data_div/fire_89/Fire_48_jd_191.png', 'Data/eval_data_div/fire_89/Fire_48_jd_190.png', 'Data/eval_data_div/fire_89/Fire_48_jd_192.png']
# W1123 17:08:07.397040 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 14.786881
# ['Data/eval_data_div/fire_92/Fire_48_jd_194.png', 'Data/eval_data_div/fire_92/Fire_48_jd_195.png', 'Data/eval_data_div/fire_92/Fire_48_jd_191.png', 'Data/eval_data_div/fire_92/Fire_48_jd_192.png', 'Data/eval_data_div/fire_92/Fire_48_jd_193.png']
# W1123 17:08:11.738975 4660258240 image.py:693] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Perceptual Distance :- 13.388254

# %%
from keras.layers import Lambda, Reshape, Permute, Input, add, Conv3D, GaussianNoise, concatenate
from keras.layers import ConvLSTM2D, BatchNormalization, TimeDistributed, Add
from keras.models import Model

def slice(x):
    return x[:,:,:,:, -1]

config=hyperparams


c=4

inp = Input((config['height'], config['width'], 5 * 3))
reshaped = Reshape((375,375,5,3))(inp)
permuted = Permute((1,2,4,3))(reshaped)
noise = GaussianNoise(0.1)(permuted)
last_layer = Lambda(slice, input_shape=(375,375,3,5), output_shape=(375,375,3))(noise)
x = Permute((4,1,2,3))(noise)
x =(ConvLSTM2D(filters=c, kernel_size=(3,3),padding='same',name='conv_lstm1', return_sequences=True))(x)


c1=(BatchNormalization())(x)
x = Dropout(0.2)(x)
x =(TimeDistributed(MaxPooling2D(pool_size=(2,2))))(c1)

x =(ConvLSTM2D(filters=2*c,kernel_size=(3,3),padding='same',name='conv_lstm3',return_sequences=True))(x)
c2=(BatchNormalization())(x)
print(c2.shape)
x = Dropout(0.2)(x)

x =(TimeDistributed(MaxPooling2D(pool_size=(2,2))))(c2)
x =(ConvLSTM2D(filters=4*c,kernel_size=(3,3),padding='same',name='conv_lstm4',return_sequences=True))(x)

x =(TimeDistributed(UpSampling2D(size=(2, 2))))(x)
x =(ConvLSTM2D(filters=4*c,kernel_size=(3,3),padding='same',name='conv_lstm5',return_sequences=True))(x)
x =(BatchNormalization())(x)
print(x.shape)

x =(ConvLSTM2D(filters=2*c,kernel_size=(3,3),padding='same',name='conv_lstm6',return_sequences=True))(x)
x =(BatchNormalization())(x)
print(x.shape)
x = Add()([c2, x])
x = Dropout(0.2)(x)

x =(TimeDistributed(UpSampling2D(size=(2, 2))))(x)
x =(ConvLSTM2D(filters=c,kernel_size=(3,3),padding='same',name='conv_lstm7',return_sequences=False))(x)
x =(BatchNormalization())(x)
combined = concatenate([last_layer, x])
combined = Conv2D(3, (1,1))(combined)
model=Model(inputs=[inp], outputs=[combined])

model.compile(optimizer='adam', loss='mse', metrics=[perceptual_distance])

model.fit_generator(my_generator(config['batch_size'], train_dir),
                    steps_per_epoch=steps_per_epoch//4,
                    epochs=config['num_epochs'], callbacks=[
    ImageCallback()],
    validation_steps=validation_steps//4,
    validation_data=my_generator(config['batch_size'], val_dir))
# Out:
# W1117 19:48:53.057636 4598126016 deprecation_wrapper.py:119] From /Users/vaibhav/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-6c435e87122b> in <module>
#      36 x =(ConvLSTM2D(filters=2*c,kernel_size=(3,3),padding='same',name='conv_lstm6',return_sequences=True))(x)
#      37 x =(BatchNormalization())(x)
# ---> 38 x = Add()([c2, x])
#      39 x = Dropout(0.2)(x)
#      40
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     461                                          'You can build it manually via: '
#     462                                          '`layer.build(batch_input_shape)`')
# --> 463                 self.build(unpack_singleton(input_shapes))
#     464                 self.built = True
#     465
#
# ~/anaconda3/lib/python3.7/site-packages/keras/layers/merge.py in build(self, input_shape)
#      89                 shape = input_shape[i][1:]
#      90             output_shape = self._compute_elemwise_op_output_shape(output_shape,
# ---> 91                                                                   shape)
#      92         # If the inputs have different ranks, we have to reshape them
#      93         # to make them broadcastable.
#
# ~/anaconda3/lib/python3.7/site-packages/keras/layers/merge.py in _compute_elemwise_op_output_shape(self, shape1, shape2)
#      59                     raise ValueError('Operands could not be broadcast '
#      60                                      'together with shapes ' +
# ---> 61                                      str(shape1) + ' ' + str(shape2))
#      62                 output_shape.append(i)
#      63         return tuple(output_shape)
#
# ValueError: Operands could not be broadcast together with shapes (5, 187, 187, 8) (5, 186, 186, 8)
